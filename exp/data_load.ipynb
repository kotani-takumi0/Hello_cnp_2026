# %%
# !pip install signate

# %%
# !signate --help
# Out:
# Usage: signate [OPTIONS] COMMAND [ARGS]...
#
# Options:
#   --version  Show the version and exit.
#   --help     Show this message and exit.
#
# Commands:
#   competition-list
#   download
#   file-list
#   submit
#   task-list
#   token

# %%
# !signate token -e takumi43290@icloud.com
# Out:
# Password:
# The API Token has been downloaded successfully.

# %%
# !signate competition-list
# Out:
# public_key                        title                                                                               remaining    reward      entry_count
# --------------------------------  ----------------------------------------------------------------------------------  -----------  --------  -------------
# 098a4365f4514c2fa197d4e16548b3bb  AI Engineering Challenge                                                            16 days      120万円             862
# 54ee8a27750e4c8cb053d3aec3e2cebf  SIGNATE × TECH OCEAN Student Cup 2026                                               31 days      21万円              198
# 0f73f92293664c48b365e08ec15161d9  NEDO Challenge Baggage-Loading Robot  コンテスト2: 積付アルゴリズム スクリーニング  77 days      1500万円            632

# %%
# !signate task-list --competition_key=54ee8a27750e4c8cb053d3aec3e2cebf
# Out:
# public_key                        task_name
# --------------------------------  --------------------
# 5c1e7372379244518cd7aeda907af953  DX教育商材の購入予測

# %%
# !signate file-list --task_key=5c1e7372379244518cd7aeda907af953
# Out:
# public_key                        file_name          title                 file_size
# --------------------------------  -----------------  --------------------  -----------
# 0bafdf1a009448139e557ebcf29cd631  train.csv          学習用データ          3.15 MB
# 8cc5f6bb14974fcd9390995badf6255c  test.csv           評価用データ          3.35 MB
# 64b8aa39fc2e4d57b77f89d4b2fe72ec  sample_submit.csv  サンプル投稿ファイル  5.22 KB
# 102da22f3a564217b198f8149417ad2e  description.csv    特徴量説明ファイル    4.80 KB

# %%
# !mkdir -p ./data

# !signate download --task_key=5c1e7372379244518cd7aeda907af953 --file_key=0bafdf1a009448139e557ebcf29cd631 --path=./data/train.csv
# !signate download --task_key=5c1e7372379244518cd7aeda907af953 --file_key=8cc5f6bb14974fcd9390995badf6255c --path=./data/test.csv
# !signate download --task_key=5c1e7372379244518cd7aeda907af953 --file_key=64b8aa39fc2e4d57b77f89d4b2fe72ec --path=./data/sample_submit.csv
# !signate download --task_key=5c1e7372379244518cd7aeda907af953 --file_key=102da22f3a564217b198f8149417ad2e --path=./data/description.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
